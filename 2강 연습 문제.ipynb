# %%
# execute autotime 
# %load_ext autotime
# Out:
# time: 202 µs (started: 2021-06-17 16:41:56 +09:00)

# %% [markdown]
# ![Screenshot%20from%202021-06-17%2014-46-56.png](attachment:Screenshot%20from%202021-06-17%2014-46-56.png)

# %%
# by me
# n , k = map(int, input().split())
n, k = 170, 3
count = 0

while n != 1 :
    count += 1
    if n%k == 0:
        n = n//k
    else:
        n = n-1
        
print(count)
# Out:
# 9
# time: 718 µs (started: 2021-06-17 17:36:46 +09:00)

# %%
# by DB
# n , k = map(int, input().split())
n, k = 170, 3

result = 0

while True:
    # n이 k로 나누어 떨어지는 수가 될 때까지 빼기
    target = (n//k) * k
    result += (n - target)
    n = target
    # n이 k보다 작을 때
    if n < k:
        break
    # k로 나누기
    result += 1
    n //= k

    
# 마지막으로 남은 수에 대하여 1씩 빼기
result += (n - 1)
print(result)
# Out:
# 9
# time: 1.02 ms (started: 2021-06-17 17:36:46 +09:00)

# %% [markdown]
# 좋은 코드란 무엇일까,
# 가볍고 빨리 돌아가는 코드가 좋은 거라면 둘이 삐까삐까 하고
#
# 알고리즘이 견고하게 들어있는게 좋은 코드라면 나동빈님 코드 같고
#
# 읽기 쉬운 코드가 좋은 코드라면 내 코드 같은데
